# %%
import pandas as pd
from pandas import DataFrame as df
#file = pd.read_csv('FIFA.csv')

# %%
# file

# %%
import nltk

# %%
import emoji
def extract_emojis(str_):
    for c in str_:
        if c in emoji.UNICODE_EMOJI:
            return 1
#         else:
#             return 0
#     return ''.join(c for c in str if c in emoji.UNICODE_EMOJI)
# extract_emojis('@Cristiano @dubaiholding LIKE For #Salah RERT @iamtridha: Football Fever is here ')

# %%
# file['emoji'] = file['Orig_Tweet'].apply(extract_emojis)

# %%
# file

# %%
# file[file['emoji'] == True]

# %%
#import modules for api 
import tweepy
from tweepy import OAuthHandler
import os

# %%
consumer_key = "---------------------"
consumer_secret_key = "-----------------------------------------------"
access_token = "---------------------------------------------------"
access_secret = "---------------------------------"

auth = OAuthHandler(consumer_key, consumer_secret_key )
auth.set_access_token(access_token ,access_secret )

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
d = {}
result = []
for tweet in tweepy.Cursor(api.search, q = '#FIFAworldcup2018', lang = "en" ).items(200):
    result.append(tweet.text)

# %%
import re
result2 = []
for i in range(0, len(result)):
    txt = ' '.join(word for word in result[i].split() if not word.startswith("https:"))  #removes link
#     rmv = re.findall(r'[a-zA-Z]+', txt)                           #removes other lang text and digits
    result2.append(txt)
    result2 = [y for y in result2 if y != '']                     #removes null value

    
d['Tweet'] = result2

# %%
import numpy as np
d2 = df(d)

# %%
d2['Tweet']
# Out:
# 0      RT @TruthInsideOut: Is Jesus GOD? The Bible sa...
# 1      RT @syma_ansari1: #EmergingPakistan initiative...
# 2      RT @syma_ansari1: #EmergingPakistan initiative...
# 3      RT @syma_ansari1: #EmergingPakistan initiative...
# 4      RT @syma_ansari1: #EmergingPakistan initiative...
# 5      RT @syma_ansari1: #EmergingPakistan initiative...
# 6      RT @syma_ansari1: #EmergingPakistan initiative...
# 7      RT @syma_ansari1: #EmergingPakistan initiative...
# 8      RT @syma_ansari1: #EmergingPakistan initiative...
# 9      RT @syma_ansari1: #EmergingPakistan initiative...
# 10     RT @syma_ansari1: #EmergingPakistan initiative...
# 11     RT @syma_ansari1: #EmergingPakistan initiative...
# 12     RT @syma_ansari1: #EmergingPakistan initiative...
# 13     RT @syma_ansari1: #EmergingPakistan initiative...
# 14     RT @syma_ansari1: #EmergingPakistan initiative...
# 15     RT @syma_ansari1: #EmergingPakistan initiative...
# ...

# %%
d2['emoji'] = d2['Tweet'].apply(extract_emojis)

# %%
df3 = d2[d2['emoji'] == 1.0]

# %%
# import emoji

def extract_all_emojis(s):
    return ''.join(c for c in s if c in emoji.UNICODE_EMOJI)

# # print(extract_emojis('@Cristiano @dubaiholding LIKE For #Salah ❤️ ❤ ❤ ❤ ❤ RERT @iamtridha'))

# %%
df3['All emojis'] = df3['Tweet'].apply(extract_all_emojis)
# del df3['All emojies']
df3
# Out:
# c:\users\anand\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                                  Tweet  emoji All emojis
# 0    RT @TruthInsideOut: Is Jesus GOD? The Bible sa...    1.0          💬
# 25   RT @TruthInsideOut: Is Jesus GOD? The Bible sa...    1.0          💬
# 29   RT @socialightng: POGBA: “Messi or no Messi, I...    1.0          😂
# 31   RT @TruthInsideOut: Is Jesus GOD? The Bible sa...    1.0          💬
# 36   RT TruthInsideOut: Is Jesus GOD? The Bible say...    1.0          💬
# 37   RT TruthInsideOut: Is Jesus GOD? The Bible say...    1.0          💬
# ...

# %%
df3['Tweet'][63]
# Out:
# 'RT @TruthInsideOut: Is Jesus GOD? The Bible says NO 💬Chat now: #GER #SWE #GERSWE #ENG #PAN #ENGPAN #JPN #SEN #JPN…'

# %%
emojie_list = []
for e in df3['All emojis']:
    for e in e:
        if e != '💬' and e != '🔁':
            emojie_list.append(e)
        
s_emoji = set(emojie_list)
# Out:
# {'🍻', '💚', '💪', '😁', '😂', '😉', '😻'}

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import emoji
def print_emojis(str_):
    for c in str_:
        if c in emoji.UNICODE_EMOJI:
            return c

# %%
sns.catplot( x = 'All emojis',kind = 'count', data = df3)

# %%
from IPython import display
import math
from pprint import pprint
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer

# %%
#sentiment analysis of tweet fifa
# import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

sia = SIA()
results = []

for line in file['Orig_Tweet']:
    tokenizer = RegexpTokenizer(r'\w+')
    line2 = ' '.join(tokenizer.tokenize(line))
    pol_score = sia.polarity_scores(line2)
    pol_score['Orig_Tweet'] = line2
    results.append(pol_score)

pprint(results[:5], width=100)

# %%
# df2 = df[['compound', 'neg', 'neu', 'pos']]

# %%
d = pd.DataFrame.from_records(results)
d.head()

# %%
df.to_csv('fifasentim.csv', mode='a', encoding='utf-8', index=False)

# %%
# from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

# sia = SIA()
# results = []

# for line in file['Orig_Tweet']:
#     tokenizer = RegexpTokenizer(r'[^\w]+')
#     line2 = ' '.join(tokenizer.tokenize(line))
#     pol_score = sia.polarity_scores(line2)
#     pol_score['Orig_Tweet'] = line2
#     results.append(pol_score)

# pprint(results[:5], width=100)
